# %%
from pymatgen.core.structure import Structure

# %%
crystal = Structure.from_file("1.cif")
# Out:
# /Users/xuhaosheng/anaconda3/envs/ml/lib/python3.11/site-packages/pymatgen/io/cif.py:1290: UserWarning: Issues encountered while parsing CIF: 34 fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))

# %%
crystal
# Out:
# Structure Summary
# Lattice
#     abc : 8.83339405 8.83339405 7.07406235
#  angles : 90.0 90.0 119.99999999999999
#  volume : 478.0295278153843
#       A : 8.83339405 0.0 5.408893874469888e-16
#       B : -4.4166970249999995 7.649943648938309 5.408893874469888e-16
#       C : 0.0 0.0 7.07406235
#     pbc : True True True
# PeriodicSite: Cr0 (Cr) (4.417, 0.0, 3.537) [0.5, 0.0, 0.5]
# PeriodicSite: Cr1 (Cr) (-2.208, 3.825, 3.537) [0.0, 0.5, 0.5]
# PeriodicSite: Cr2 (Cr) (2.208, 3.825, 3.537) [0.5, 0.5, 0.5]
# PeriodicSite: Cr3 (Cr) (-3.239e-07, 2.55, 5.895) [0.1667, 0.3333, 0.8333]
# PeriodicSite: Cr4 (Cr) (2.208, 6.375, 5.895) [0.6667, 0.8333, 0.8333]
# PeriodicSite: Cr5 (Cr) (-2.208, 6.375, 5.895) [0.1667, 0.8333, 0.8333]
# PeriodicSite: Cr6 (Cr) (4.417, 5.1, 1.179) [0.8333, 0.6667, 0.1667]
# PeriodicSite: Cr7 (Cr) (2.208, 1.275, 1.179) [0.3333, 0.1667, 0.1667]
# PeriodicSite: Cr8 (Cr) (6.625, 1.275, 1.179) [0.8333, 0.1667, 0.1667]
# ...

# %%
Structure.get_space_group_info(crystal)
# Out:
# ('R-3m', 166)
